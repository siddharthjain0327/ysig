# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import copy

# %%
# df1 = pd.read_pickle('/Users/siddharthjain/Desktop/Siddharth Jain/Yale/YSIG/YSIG Analytics/countryDict.pkl')
df2 = pd.read_pickle('/Users/siddharthjain/Desktop/Siddharth Jain/Yale/YSIG/YSIG Analytics/historicalEquityHoldings.pkl')
df3 = pd.read_pickle('/Users/siddharthjain/Desktop/Siddharth Jain/Yale/YSIG/YSIG Analytics/sectDict.pkl')
# df4 = pd.read_pickle('/Users/siddharthjain/Desktop/Siddharth Jain/Yale/YSIG/YSIG Analytics/fixedIncomeOnly.pkl')
# df5 = pd.read_pickle('/Users/siddharthjain/Desktop/Siddharth Jain/Yale/YSIG/YSIG Analytics/longOnly.pkl')
# df6 = pd.read_pickle('/Users/siddharthjain/Desktop/Siddharth Jain/Yale/YSIG/YSIG Analytics/optionsOnly.pkl')
# df7 = pd.read_pickle('/Users/siddharthjain/Desktop/Siddharth Jain/Yale/YSIG/YSIG Analytics/shortOnly.pkl')
# df8 = pd.read_pickle('/Users/siddharthjain/Desktop/Siddharth Jain/Yale/YSIG/YSIG Analytics/startingShares.pkl')
# df9 = pd.read_pickle('/Users/siddharthjain/Desktop/Siddharth Jain/Yale/YSIG/YSIG Analytics/totalTransactions.pkl')

# %%
df2.head(10)
# Out:
#     tick     buyDate    sellDate    buyPrice   sellPrice    Return  SPYReturn  \
# 1    ABT  01/03/2005  02/08/2007   14.846637   17.537888  0.181270   0.249432
# 2    PII  01/03/2005  02/08/2007   21.873255   16.865547 -0.228942   0.249432
# 3   LVLT  11/21/2005  11/21/2005    3.840000    3.790000 -0.013021   0.000000
# 4      C  01/03/2005  11/14/2006  347.211243  394.998077  0.137630   0.196243
# 5      C  03/08/2011  04/08/2011   39.940147   39.251534 -0.017241   0.006465
# 6      C  04/11/2011  07/25/2011   38.993301   34.362175 -0.118767   0.015351
# 7    SPG  01/03/2005  11/08/2007   30.865549   50.713871  0.643057   0.284449
# 8   TEVA  01/03/2005  02/08/2007   22.700497   27.592525  0.215503   0.249432
# 9   TEVA  10/31/2011  03/05/2013   34.346569   33.315838 -0.030010   0.264633
# 11    KO  01/03/2005  02/08/2007   12.413393   15.093970  0.215942   0.249432
#
#     subtractAlpha  regressAlpha  regressBeta  ...  daysHeld  tradingDaysHeld  \
# 1       -0.068162      0.000028     0.659313  ...       767              530
# 2       -0.478374     -0.000888     1.370311  ...       767              530
# 3       -0.013021           NaN          NaN  ...         1                2
# 4       -0.058613     -0.000046     0.795266  ...       681              473
# 5       -0.023707     -0.000938     0.771150  ...        32               25
# 6       -0.134119     -0.001908     1.240862  ...       106               74
# 7        0.358608      0.000375     1.250947  ...      1040              720
# 8       -0.033929      0.000142     0.728528  ...       767              530
# 9       -0.294643     -0.000449     0.592883  ...       492              337
# 11      -0.033490      0.000056     0.625760  ...       767              530
#
#     SPYReturnDaily  SPYReturnAnnual  ReturnDaily  ReturnAnnual  \
# 1         0.000420         0.111691     0.000314      0.082430
# 2         0.000420         0.111691    -0.000490     -0.116283
# 3         0.000000         0.000000    -0.006532     -0.808219
# 4         0.000379         0.100170     0.000273      0.071114
# 5         0.000258         0.067118    -0.000695     -0.160800
# 6         0.000206         0.053250    -0.001707     -0.349853
# 7         0.000348         0.091568     0.000690      0.189812
# 8         0.000420         0.111691     0.000368      0.097234
# 9         0.000697         0.191919    -0.000090     -0.022527
# 11        0.000420         0.111691     0.000369      0.097422
#
#     regressAlphaAnnualized  regressAlphaNonDaily  otherAlphaDaily  \
# 1                 0.007068              0.014924         0.000031
# 2                -0.200615             -0.375577        -0.001594
# 3                      NaN                   NaN              NaN
# 4                -0.011505             -0.021486        -0.000039
# 5                -0.210508             -0.023176        -0.000899
# 6                -0.381950             -0.131772        -0.002002
# 7                 0.099173              0.310180         0.000351
# 8                 0.036554              0.078432         0.000063
# 9                -0.106966             -0.140402        -0.000614
# 11                0.014178              0.030051         0.000110
#
#     otherAlphaAnnualized
# 1               0.007961
# 2              -0.331089
# 3                    NaN
# 4              -0.009864
# 5              -0.202740
# 6              -0.396480
# 7               0.092394
# 8               0.015924
# 9              -0.143346
# 11              0.028027
#
# [10 rows x 21 columns]

# %%
df2.columns
# Out:
# Index(['tick', 'buyDate', 'sellDate', 'buyPrice', 'sellPrice', 'Return',
#        'SPYReturn', 'subtractAlpha', 'regressAlpha', 'regressBeta',
#        'otherAlpha', 'daysHeld', 'tradingDaysHeld', 'SPYReturnDaily',
#        'SPYReturnAnnual', 'ReturnDaily', 'ReturnAnnual',
#        'regressAlphaAnnualized', 'regressAlphaNonDaily', 'otherAlphaDaily',
#        'otherAlphaAnnualized'],
#       dtype='object')

# %%
df = copy.deepcopy(df2)

# %%
df3['C']
# Out:
# 'Financial Services'

# %%
for row in df.index:
    df.loc[row, 'Industry'] = df3[df.loc[row, 'tick']]

# %%
df
# Out:
#      tick     buyDate    sellDate    buyPrice   sellPrice    Return  \
# 1     ABT  01/03/2005  02/08/2007   14.846637   17.537888  0.181270
# 2     PII  01/03/2005  02/08/2007   21.873255   16.865547 -0.228942
# 3    LVLT  11/21/2005  11/21/2005    3.840000    3.790000 -0.013021
# 4       C  01/03/2005  11/14/2006  347.211243  394.998077  0.137630
# 5       C  03/08/2011  04/08/2011   39.940147   39.251534 -0.017241
# ..    ...         ...         ...         ...         ...       ...
# 276  FUBO  11/26/2021  02/01/2022   20.570000   11.280000 -0.451629
# 277    MQ  11/26/2021  02/01/2022   21.960000   12.430000 -0.433971
# 278  TNDM  12/03/2021  02/01/2022  134.509900  120.099998 -0.107129
# 279   LAD  12/10/2021  02/01/2022  283.620000  295.929993  0.043403
# 280   DBC  01/25/2022  02/01/2022   22.152100   22.510000  0.016156
#
#      SPYReturn  subtractAlpha  regressAlpha  regressBeta  ...  \
# 1     0.249432      -0.068162      0.000028     0.659313  ...
# 2     0.249432      -0.478374     -0.000888     1.370311  ...
# 3     0.000000      -0.013021           NaN          NaN  ...
# 4     0.196243      -0.058613     -0.000046     0.795266  ...
# 5     0.006465      -0.023707     -0.000938     0.771150  ...
# ..         ...            ...           ...          ...  ...
# 276  -0.009649      -0.441979     -0.011893     3.303121  ...
# 277  -0.009649      -0.424322     -0.011152     2.497935  ...
# 278   0.002473      -0.109602     -0.002302     1.591111  ...
# 279  -0.034411       0.077814      0.001792     0.931776  ...
# 280   0.042535      -0.026378           NaN          NaN  ...
#
#      tradingDaysHeld  SPYReturnDaily  SPYReturnAnnual  ReturnDaily  \
# 1                530        0.000420         0.111691     0.000314
# 2                530        0.000420         0.111691    -0.000490
# 3                  2        0.000000         0.000000    -0.006532
# 4                473        0.000379         0.100170     0.000273
# 5                 25        0.000258         0.067118    -0.000695
# ..               ...             ...              ...          ...
# 276               47       -0.000206        -0.050659    -0.012702
# 277               47       -0.000206        -0.050659    -0.012036
# 278               42        0.000059         0.014930    -0.002694
# 279               37       -0.000946        -0.212187     0.001149
# 280                7        0.005968         3.479786     0.002292
#
#      ReturnAnnual  regressAlphaAnnualized  regressAlphaNonDaily  \
# 1        0.082430                0.007068              0.014924
# 2       -0.116283               -0.200615             -0.375577
# 3       -0.808219                     NaN                   NaN
# 4        0.071114               -0.011505             -0.021486
# 5       -0.160800               -0.210508             -0.023176
# ..            ...                     ...                   ...
# 276     -0.960098               -0.950959             -0.430125
# 277     -0.952707               -0.940753             -0.409674
# 278     -0.493321               -0.440473             -0.092242
# 279      0.335592                0.570354              0.068507
# 280      0.780662                     NaN                   NaN
#
#      otherAlphaDaily  otherAlphaAnnualized                Industry
# 1           0.000031              0.007961              Healthcare
# 2          -0.001594             -0.331089       Consumer Cyclical
# 3                NaN                   NaN             Unavailable
# 4          -0.000039             -0.009864      Financial Services
# 5          -0.000899             -0.202740      Financial Services
# ..               ...                   ...                     ...
# 276        -0.011514             -0.945981  Communication Services
# 277        -0.011159             -0.940858              Technology
# 278        -0.002799             -0.506572              Healthcare
# 279         0.001968              0.641347       Consumer Cyclical
# 280              NaN                   NaN             Unavailable
#
# [273 rows x 22 columns]
